# %%
# Install Dependencies for Ollama
# !apt-get update > apt.log 2>&1 && apt-get install zstd lshw >> apt.log 2>&1

# %%
# Download Ollama
# !curl -fsSL https://ollama.com/install.sh | sh > ollama_setup.log 2>&1

# %%
# Start Ollama
# !nohup ollama serve > ollama.log 2>&1 &

# %%
# Pull Models
# !ollama pull deepseek-r1:7b > ollama_model_setup.log 2>&1 # LLM
# !ollama pull nomic-embed-text >> ollama_model_setup.log 2>&1 # Embeddings

# %%
# Stop Ollama
# !pkill -f "ollama serve"
